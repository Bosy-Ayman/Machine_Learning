# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.datasets import load_iris
from  sklearn import datasets
from collections import Counter
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import Normalizer
from sklearn.linear_model import LinearRegression
import random

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xvalues = []
yvalues = []
for x in range(0,6):
  y = 3*x+2
  xvalues.append(x)
  yvalues.append(y)

# %%
plt.scatter(xvalues, yvalues)

# %%
values = {'x':xvalues,'y':yvalues}
df = pd.DataFrame(values)
df.head()
# Out:
#    x   y
# 0  0   2
# 1  1   5
# 2  2   8
# 3  3  11
# 4  4  14

# %%
x =df['x'].to_numpy()
y=df['y'].to_numpy()
print('x values :',x)
print('y values :',y)
x = x.reshape((-1, 1))
y = y.reshape((-1, 1))
print(x)
reg = LinearRegression().fit(x, y)
predictions = reg.predict(x)
print('Predictions:', predictions)
# Out:
# x values : [0 1 2 3 4 5]
# y values : [ 2  5  8 11 14 17]
# [[0]
#  [1]
#  [2]
#  [3]
#  [4]
#  [5]]
# Predictions: [[ 2.]
#  [ 5.]
#  [ 8.]
#  [11.]
#  [14.]
#  [17.]]

# %%
plt.scatter(x, y, color='blue', label='Actual data')
plt.plot(x, predictions, color='red', linewidth=2, label='Linear Regression')

# %%
xvalues2 = []
yvalues2 = []

for x in range(0, 6):
    y = 3 * x + 2 + random.uniform(0, 1)
    xvalues2.append(x)
    yvalues2.append(y)

print("X values:", xvalues2)
print("Y values:", yvalues2)
# Out:
# X values: [0, 1, 2, 3, 4, 5]
# Y values: [2.9085253401458555, 5.371634054000767, 8.522075513519555, 11.401656196189938, 14.590098892714712, 17.60419696613652]

# %%
plt.scatter(xvalues2, yvalues2)

# %%
values2 = {'x2':xvalues2,'y2':yvalues2}
df = pd.DataFrame(values2)
df.head()
# Out:
#    x2         y2
# 0   0   2.908525
# 1   1   5.371634
# 2   2   8.522076
# 3   3  11.401656
# 4   4  14.590099

# %%
x2 =df['x2'].to_numpy()
y2 =df['y2'].to_numpy()
print('x values :',x)
print('y values :',y)
x2 = x2.reshape((-1, 1))
y2 = y2.reshape((-1, 1))
print(x2)
reg = LinearRegression().fit(x2, y2)
predictions2 = reg.predict(x2)
print('Predictions:', predictions2)
# Out:
# x values : 5
# y values : 17.60419696613652
# [[0]
#  [1]
#  [2]
#  [3]
#  [4]
#  [5]]
# Predictions: [[ 2.63684068]
#  [ 5.60865021]
#  [ 8.58045973]
#  [11.55226926]
#  [14.52407878]
#  [17.4958883 ]]

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
print("Mean Squared Error:", mean_squared_error(y,predictions))
print("Mean Squared Error:", mean_squared_error(y,predictions2))
# Out:
# Mean Squared Error: 91.92800846593639
# Mean Squared Error: 82.57790292924582

# %%
plt.scatter(x2, y2, color='blue', label='Actual data')
plt.plot(x2, predictions2, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iris = datasets.load_iris()

# %%
_, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target)
ax.set(xlabel=iris.feature_names[0], ylabel=iris.feature_names[1])
_ = ax.legend(
    scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes"
)

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
iris_df.insert(0, 'augmented', 1)

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
class1 = iris_df[iris_df['target'] == 0]
class2 = iris_df[iris_df['target'].isin([1, 2])]

# %%
train_Class1,test_Class1= train_test_split(class1 ,test_size=0.2, random_state=42)
train_Class2,test_Class2= train_test_split(class2 ,test_size=0.2, random_state=42)

# %%
train_Class2=train_2*-1

# %%
NPtrain_Class1=train_Class1.to_numpy()
NPtrain_Class2=train_Class2.to_numpy()

# %%
Train=np.concatenate((NPtrain_Class1,NPtrain_Class2), axis=0)
Train
# Out:
# array([[ 4.8,  3. ,  1.4,  0.1,  0. ],
#        [ 5. ,  3.6,  1.4,  0.2,  0. ],
#        [ 4.9,  3.6,  1.4,  0.1,  0. ],
#        [ 4.4,  2.9,  1.4,  0.2,  0. ],
#        [ 4.6,  3.1,  1.5,  0.2,  0. ],
#        [ 4.6,  3.4,  1.4,  0.3,  0. ],
#        [ 4.5,  2.3,  1.3,  0.3,  0. ],
#        [ 5.1,  3.8,  1.6,  0.2,  0. ],
#        [ 4.6,  3.2,  1.4,  0.2,  0. ],
#        [ 5.7,  4.4,  1.5,  0.4,  0. ],
#        [ 4.9,  3.1,  1.5,  0.1,  0. ],
#        [ 5.4,  3.9,  1.3,  0.4,  0. ],
#        [ 4.8,  3.4,  1.9,  0.2,  0. ],
#        [ 4.9,  3.1,  1.5,  0.2,  0. ],
#        [ 5.4,  3.4,  1.5,  0.4,  0. ],
#        [ 5.1,  3.5,  1.4,  0.2,  0. ],
#        [ 5.1,  3.8,  1.9,  0.4,  0. ],
#        [ 5.2,  3.5,  1.5,  0.2,  0. ],
#        [ 5.5,  4.2,  1.4,  0.2,  0. ],
#        [ 5.4,  3.9,  1.7,  0.4,  0. ],
#        [ 4.7,  3.2,  1.6,  0.2,  0. ],
#        [ 4.8,  3.4,  1.6,  0.2,  0. ],
#        [ 5.5,  3.5,  1.3,  0.2,  0. ],
#        [ 4.9,  3. ,  1.4,  0.2,  0. ],
#        [ 5.1,  3.7,  1.5,  0.4,  0. ],
#        [ 4.7,  3.2,  1.3,  0.2,  0. ],
#        [ 5. ,  3.5,  1.6,  0.6,  0. ],
#        [ 5. ,  3.2,  1.2,  0.2,  0. ],
#        [ 5.1,  3.3,  1.7,  0.5,  0. ],
#        [ 5. ,  3.5,  1.3,  0.3,  0. ],
#        [ 5.4,  3.7,  1.5,  0.2,  0. ],
#        [ 4.6,  3.6,  1. ,  0.2,  0. ],
#        [ 5.7,  3.8,  1.7,  0.3,  0. ],
#        [ 5. ,  3.3,  1.4,  0.2,  0. ],
#        [ 5.4,  3.4,  1.7,  0.2,  0. ],
#        [ 5. ,  3.4,  1.5,  0.2,  0. ],
#        [ 4.4,  3.2,  1.3,  0.2,  0. ],
#        [ 5.8,  4. ,  1.2,  0.2,  0. ],
#        [ 5.2,  3.4,  1.4,  0.2,  0. ],
#        [ 4.4,  3. ,  1.3,  0.2,  0. ],
#        [-7.6, -3. , -6.6, -2.1, -2. ],
#        [-6. , -3. , -4.8, -1.8, -2. ],
#        [-6.8, -2.8, -4.8, -1.4, -1. ],
#        [-5.8, -2.6, -4. , -1.2, -1. ],
#        [-6. , -2.2, -5. , -1.5, -2. ],
#        [-6.7, -3.1, -4.4, -1.4, -1. ],
#        [-5.5, -2.6, -4.4, -1.2, -1. ],
#        [-6.3, -2.5, -5. , -1.9, -2. ],
#        [-5.2, -2.7, -3.9, -1.4, -1. ],
#        [-7.7, -2.8, -6.7, -2. , -2. ],
#        [-5.9, -3. , -4.2, -1.5, -1. ],
#        [-6.2, -2.9, -4.3, -1.3, -1. ],
#        [-7.7, -3. , -6.1, -2.3, -2. ],
#        [-6. , -2.9, -4.5, -1.5, -1. ],
#        [-6.8, -3.2, -5.9, -2.3, -2. ],
#        [-5.7, -2.8, -4.5, -1.3, -1. ],
#        [-6.5, -3. , -5.5, -1.8, -2. ],
#        [-6.4, -3.2, -5.3, -2.3, -2. ],
#        [-6. , -3.4, -4.5, -1.6, -1. ],
#        [-5.6, -3. , -4.5, -1.5, -1. ],
#        [-5.7, -2.8, -4.1, -1.3, -1. ],
#        [-5.4, -3. , -4.5, -1.5, -1. ],
#        [-4.9, -2.4, -3.3, -1. , -1. ],
#        [-6.7, -3. , -5.2, -2.3, -2. ],
#        [-6.7, -3. , -5. , -1.7, -1. ],
#        [-5.6, -2.5, -3.9, -1.1, -1. ],
#        [-7.9, -3.8, -6.4, -2. , -2. ],
#        [-6.6, -3. , -4.4, -1.4, -1. ],
#        [-6.8, -3. , -5.5, -2.1, -2. ],
#        [-6.1, -2.9, -4.7, -1.4, -1. ],
#        [-6.4, -2.9, -4.3, -1.3, -1. ],
#        [-5.5, -2.3, -4. , -1.3, -1. ],
#        [-5.8, -2.7, -4.1, -1. , -1. ],
#        [-5.6, -3. , -4.1, -1.3, -1. ],
#        [-6.6, -2.9, -4.6, -1.3, -1. ],
#        [-6.4, -2.8, -5.6, -2.1, -2. ],
#        [-6.3, -3.3, -4.7, -1.6, -1. ],
#        [-5.8, -2.8, -5.1, -2.4, -2. ],
#        [-6.7, -3.1, -4.7, -1.5, -1. ],
#        [-6.9, -3.1, -5.4, -2.1, -2. ],
#        [-4.9, -2.5, -4.5, -1.7, -2. ],
#        [-5.9, -3. , -5.1, -1.8, -2. ],
#        [-6.5, -3. , -5.8, -2.2, -2. ],
#        [-5. , -2.3, -3.3, -1. , -1. ],
#        [-6.3, -3.3, -6. , -2.5, -2. ],
#        [-7.7, -3.8, -6.7, -2.2, -2. ],
#        [-5.7, -2.9, -4.2, -1.3, -1. ],
#        [-7.7, -2.6, -6.9, -2.3, -2. ],
#        [-6.4, -2.7, -5.3, -1.9, -2. ],
#        [-6.5, -3. , -5.2, -2. , -2. ],
#        [-7.2, -3. , -5.8, -1.6, -2. ],
#        [-6.1, -3. , -4.6, -1.4, -1. ],
#        [-6.7, -2.5, -5.8, -1.8, -2. ],
#        [-5.1, -2.5, -3. , -1.1, -1. ],
#        [-6.2, -3.4, -5.4, -2.3, -2. ],
#        [-7.3, -2.9, -6.3, -1.8, -2. ],
#        [-7.2, -3.2, -6. , -1.8, -2. ],
#        [-5.8, -2.7, -3.9, -1.2, -1. ],
#        [-6.7, -3.3, -5.7, -2.5, -2. ],
#        [-7.2, -3.6, -6.1, -2.5, -2. ],
#        [-5.7, -2.5, -5. , -2. , -2. ],
#        [-6.1, -2.6, -5.6, -1.4, -2. ],
#        [-6.3, -2.3, -4.4, -1.3, -1. ],
#        [-5.7, -2.6, -3.5, -1. , -1. ],
#        [-6.4, -3.2, -4.5, -1.5, -1. ],
#        [-7.1, -3. , -5.9, -2.1, -2. ],
#        [-6.1, -2.8, -4. , -1.3, -1. ],
#        [-6.9, -3.1, -4.9, -1.5, -1. ],
#        [-6.1, -2.8, -4.7, -1.2, -1. ],
#        [-6.4, -3.1, -5.5, -1.8, -2. ],
#        [-6.9, -3.1, -5.1, -2.3, -2. ],
#        [-6.7, -3.3, -5.7, -2.1, -2. ],
#        [-6.3, -3.4, -5.6, -2.4, -2. ],
#        [-6.4, -2.8, -5.6, -2.2, -2. ],
#        [-5.9, -3.2, -4.8, -1.8, -1. ],
#        [-6.5, -3.2, -5.1, -2. , -2. ],
#        [-5.6, -2.8, -4.9, -2. , -2. ],
#        [-5.6, -2.9, -3.6, -1.3, -1. ],
#        [-5.8, -2.7, -5.1, -1.9, -2. ],
#        [-5.8, -2.7, -5.1, -1.9, -2. ]])

# %%
def MSSE(x):
  ones_column = np.ones((x.shape[0], 1), dtype=x.dtype)
  x_T = x.transpose()
  xx_T=np.matmul(x_T,x)
  xfinalInv = np.linalg.inv(xx_T)
  pseudoInv=np.matmul(xfinalInv,x_T)
  w=np.matmul(pseudoInv,ones_column)
  return w

# %%
MSSE(Train)
# Out:
# array([[ 0.05044236],
#        [ 0.42607328],
#        [-0.49970596],
#        [-0.40834285],
#        [ 0.44871944]])

# %%
for i in range(len(test_2)):
  test=test_2.values[i]
  print(np.dot(test,MSSE(Train)))
# Out:
# [-0.75278376]
# [-1.08253226]
# [-1.17858689]
# [-0.57431574]
# [-0.74801624]
# [-0.73833394]
# [-1.22938399]
# [-1.36034027]
# [-0.60423593]
# [-0.75504757]
# [-1.16236783]
# [-0.59933151]
# [-0.81795275]
# [-1.30007752]
# [-1.22214638]
# [-0.94156175]
# [-0.73041906]
# [-0.70021924]
# [-0.71843189]
# [-0.50852663]

# %%
for i in range(len(test_Class2)):
  test=test_Class2.values[i]
  print(np.dot(test,MSSE(Train)))
# Out:
# [-0.75278376]
# [-1.08253226]
# [-1.17858689]
# [-0.57431574]
# [-0.74801624]
# [-0.73833394]
# [-1.22938399]
# [-1.36034027]
# [-0.60423593]
# [-0.75504757]
# [-1.16236783]
# [-0.59933151]
# [-0.81795275]
# [-1.30007752]
# [-1.22214638]
# [-0.94156175]
# [-0.73041906]
# [-0.70021924]
# [-0.71843189]
# [-0.50852663]
